# %% [markdown]
# ## 믿:음 Languege Model preview

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, GenerationConfig
print(torch.cuda.is_available())
# Out:
# True

# %%
# Mini로 test
model_name = "K-intelligence/Midm-2.0-Mini-Instruct"

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype=torch.bfloat16,
    trust_remote_code=True,
    device_map="auto"
)
tokenizer = AutoTokenizer.from_pretrained(model_name)
generation_config = GenerationConfig.from_pretrained(model_name)

# %%
# prompting - 시계열적인 정보를 이해할 수 있는가?
prompt = "20250103 1300 \
20250104 1307 \
20250810 1401 \
\
오늘 날짜는 2025년 8월 25일이야 \
기록된 데이터의 가장 최근날짜의 환율이 몇이야?"

# message for inference
messages = [
    {"role": "system", 
     "content": "시계열 정보를 잘 이해하고 전후 관계를 정확하게 파악하여야 한다."},
    {"role": "user", "content": prompt}
]

input_ids = tokenizer.apply_chat_template(
    messages,
    tokenize=True,
    add_generation_prompt=True,
    return_tensors="pt"
)

# %%
output = model.generate(
    input_ids.to("cuda"),
    generation_config=generation_config,
    eos_token_id=tokenizer.eos_token_id,
    max_new_tokens=256,
    do_sample=False,
)
print(tokenizer.decode(output[0]))
# Out:
# The following generation flags are not valid and may be ignored: ['temperature', 'top_p', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2024
# Today Date: 26 Aug 2025
#
# Mi:dm(믿:음)은 KT에서 개발한 AI 기반 어시스턴트이다. 너는 Mi:dm으로서 사용자에게 유용하고 안전한 응답을 제공해야 한다.
#
# Mi:dm은 December 2024까지의 지식으로 학습되었으며 그 외의 지식을 묻는 경우에는 한계를 인정해야 한다.
# 오늘 날짜는 26 Aug 2025임을 참고하여 응답을 제공한다.
#
# 어시스턴트는 기본적으로 "한국어"를 사용한다. 사용자의 요청에 따라 생각하고 응답하는 언어는 달라질 수 있으며, 다른 요구사항이 없다면 입력 언어를 따라 응답하라.
# 코드 작성 시에는 요구되는 언어의 소스코드로 작성해야 하며, STEM(과학, 기술, 공학, 수학) 분야의 전문 용어는 원문을 그대로 유지하여 출력한다.
#
# Mi:dm은 사용자 친화적으로 답변을 제공해야 한다. 사용자의 요청이 없다면 기본적으로 경어체를 사용해야 한다.
# ...

# %% [markdown]
# ## Agentic RAG test

# %%
# fx_hedge_agent_poc.py
import os, math, datetime
# import yfinance as yf
from typing import List
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

# 1) 믿:음 2.0 로딩 (HF 로컬)
MODEL_ID = "K-intelligence/Midm-2.0-Mini-Instruct"  # 또는 Mini
dtype = torch.bfloat16 if torch.cuda.is_available() else torch.float32
tok = AutoTokenizer.from_pretrained(MODEL_ID, use_fast=True)
mdl = AutoModelForCausalLM.from_pretrained(MODEL_ID, torch_dtype=dtype, device_map="auto", trust_remote_code=True)

# 2) LangChain 래핑
from langchain_huggingface import HuggingFacePipeline, ChatHuggingFace
gen = pipeline(
    "text-generation",
    model=mdl, tokenizer=tok,
    max_new_tokens=512, do_sample=False, temperature=0.2, top_p=0.95,
    eos_token_id=tok.eos_token_id
)
llm = HuggingFacePipeline(pipeline=gen)
chat = ChatHuggingFace(llm=llm)  # LangChain ChatModel로 사용
# 참고: ChatHuggingFace는 HF Pipeline/Endpoint/Hub 모두 지원. :contentReference[oaicite:1]{index=1}

# 3) (선택) RAG: 회사 노출 문서 인덱스
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
emb = HuggingFaceEmbeddings(model_name="sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2")

def build_exposure_retriever(txt_paths: List[str]):
    texts = []
    for p in txt_paths:
        with open(p, "r", encoding="utf-8", errors="ignore") as f:
            texts.append(f.read())
    splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
    docs = splitter.create_documents(texts)
    vs = FAISS.from_documents(docs, emb)
    return vs.as_retriever(search_kwargs={"k": 4})

# 예시 노출 문서(없으면 RAG 생략)
retriever = None
if all(os.path.exists(p) for p in ["exposure_policy.txt"]):
    retriever = build_exposure_retriever(["exposure_policy.txt"])

# 4) Tools 정의 (@tool 데코레이터 사용)
from langchain_core.tools import tool

@tool("get_fx_spot")
def get_fx_spot(pair: str = "USDKRW") -> str:
    """yfinance에서 최근 종가 스팟을 가져온다. 예: 'USDKRW' 또는 'KRW=X'."""
    sym = pair if pair.endswith("=X") else (pair if pair.count("=")==1 else "USDKRW=X")
    data = yf.download(sym, period="5d", interval="1d", progress=False)
    if data.empty:
        return f"no data for {pair}"
    px = float(data["Close"].iloc[-1])
    dt = str(data.index[-1].date())
    return f"{pair} spot_close={px:.4f} on {dt}"

@tool("get_rates")
def get_rates(domestic_annual: float, foreign_annual: float, tenor_days: int = 90) -> str:
    """연 단리 금리(%)와 만기일수로 단순 변환. 실무에선 시장금리 API로 대체."""
    rd = domestic_annual / 100.0
    rf = foreign_annual / 100.0
    T = tenor_days / 365.0
    return f"rd={rd}, rf={rf}, T={T}"

@tool("price_forward")
def price_forward(spot: float, rd: float, rf: float, T: float) -> str:
    """Covered IRP: F = S * (1+rd*T)/(1+rf*T). (연 단리 근사)"""
    F = spot * (1.0 + rd*T) / (1.0 + rf*T)
    return f"forward={F:.6f}"

@tool("lookup_exposures")
def lookup_exposures(query: str) -> str:
    """회사 내부 노출/정책 문서에서 관련 문단을 검색."""
    if retriever is None:
        return "no retriever"
    hits = retriever.get_relevant_documents(query)
    out = []
    for i, h in enumerate(hits, 1):
        out.append(f"[Doc {i}] {h.page_content[:500]}")
    return "\n\n".join(out)

tools = [get_fx_spot, get_rates, price_forward] + ([lookup_exposures] if retriever else [])

# 5) Tool-calling Agent 구성
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain.agents import create_tool_calling_agent, AgentExecutor

SYSTEM = """너는 한국 기업의 외환(USD/KRW) 헤지 조언을 초안 수준으로 생성하는 재무 어시스턴트다.
- 먼저 고객의 노출(통화, 금액, 만기, 정책)을 요약하라.
- 필요하면 도구(get_fx_spot, get_rates, price_forward, lookup_exposures)를 순차적으로 호출해 근거를 확보하라.
- 결과는 '헤지 목적 ▶ 제안 전략 ▶ 근거(수치/링크) ▶ 리스크/주의' 4단락으로 정리하라.
- 투자 자문이 아니라 학습용 시뮬레이션 초안임을 명시하라.
- 숫자는 단위(USD, KRW, bp, %)를 붙여라.
"""
prompt = ChatPromptTemplate.from_messages([
    ("system", SYSTEM),
    MessagesPlaceholder("chat_history"),
    ("human", "{input}")
])

agent = create_tool_calling_agent(chat, tools, prompt)
executor = AgentExecutor(agent=agent, tools=tools, verbose=True)

if __name__ == "__main__":
    user = (
        "당사 3개월 후 USD 2,000,000 매출 예정(원화 기준 실적 보고). "
        "기본적으로 70%를 선도환으로 커버하고 싶다. 현재 환율과 3개월 선도환 추정치로 "
        "헤지 금액/비율/대략적 선도가격을 계산해 초안을 만들어줘. "
        "국내 무위험 3.7%, 미국 5.1% 가정."
    )
    out = executor.invoke({"input": user, "chat_history": []})
    print("\n=== AGENT OUTPUT ===\n", out["output"])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 # fx_hedge_agent_poc.py
#       2 import os, math, datetime
# ----> 3 import yfinance as yf
#       4 from typing import List
#       5 import torch
#
# ModuleNotFoundError: No module named 'yfinance'
